# %%
import pandas as pd

# %%
df = pd.read_csv('~/Desktop/data/Total_Protein_Sum.csv')

# %%
df
# Out:
#       PG.MolecularWeight  PG.Genes [1] 331 SWATH.htrms.PG.Quantity  \
# 0               12468.06  IGLV7-46                        Filtered
# 1               12440.85  IGLV3-10                        Filtered
# 2               12331.71   IGLV3-9                        Filtered
# 3               12956.74  IGKV2-28                     34.48708725
# 4               12711.51  IGKV1-27                        Filtered
# ...                  ...       ...                             ...
# 3846            49960.70      SQOR                     417.9597778
# 3847           553276.75      PCLO                     2697.338135
# 3848            54284.03     WASF2                     71.50621033
# 3849            51641.10     ENPP4                     21.08303261
# 3850           111076.49   SEC23IP                      65.0891571
#
#      [2] 339 SWATH.htrms.PG.Quantity [3] 378 SWATH.htrms.PG.Quantity  \
# 0                           Filtered                     142.5664215
# ...

# %%
df.iloc[0,:] = df.iloc[0,:].replace('Filtered',0)

# %%
df
# Out:
#       PG.MolecularWeight  PG.Genes [1] 331 SWATH.htrms.PG.Quantity  \
# 0               12468.06  IGLV7-46                               0
# 1               12440.85  IGLV3-10                        Filtered
# 2               12331.71   IGLV3-9                        Filtered
# 3               12956.74  IGKV2-28                     34.48708725
# 4               12711.51  IGKV1-27                        Filtered
# ...                  ...       ...                             ...
# 3846            49960.70      SQOR                     417.9597778
# 3847           553276.75      PCLO                     2697.338135
# 3848            54284.03     WASF2                     71.50621033
# 3849            51641.10     ENPP4                     21.08303261
# 3850           111076.49   SEC23IP                      65.0891571
#
#      [2] 339 SWATH.htrms.PG.Quantity [3] 378 SWATH.htrms.PG.Quantity  \
# 0                                  0                     142.5664215
# ...

# %%
df = df.replace('Filtered',0)

# %%
df
# Out:
#       PG.MolecularWeight  PG.Genes [1] 331 SWATH.htrms.PG.Quantity  \
# 0               12468.06  IGLV7-46                               0
# 1               12440.85  IGLV3-10                               0
# 2               12331.71   IGLV3-9                               0
# 3               12956.74  IGKV2-28                     34.48708725
# 4               12711.51  IGKV1-27                               0
# ...                  ...       ...                             ...
# 3846            49960.70      SQOR                     417.9597778
# 3847           553276.75      PCLO                     2697.338135
# 3848            54284.03     WASF2                     71.50621033
# 3849            51641.10     ENPP4                     21.08303261
# 3850           111076.49   SEC23IP                      65.0891571
#
#      [2] 339 SWATH.htrms.PG.Quantity [3] 378 SWATH.htrms.PG.Quantity  \
# 0                                  0                     142.5664215
# ...

# %%
df.head(20)
# Out:
#     PG.MolecularWeight   PG.Genes [1] 331 SWATH.htrms.PG.Quantity  \
# 0             12468.06   IGLV7-46                               0
# 1             12440.85   IGLV3-10                               0
# 2             12331.71    IGLV3-9                               0
# 3             12956.74   IGKV2-28                     34.48708725
# 4             12711.51   IGKV1-27                               0
# 5             12625.24  IGKV3D-11                      77.0422821
# 6             12925.78   IGHV3-15                     77.58589172
# 7             12839.61   IGHV3-74                               0
# 8             13202.93   IGHV3-72                               0
# 9              6313.38    PIGBOS1                     40.62528992
# 10            13007.72    IGHV1-3                               0
# 11            13124.06   IGHV4-28                               0
# 12            12674.55   IGHV5-51                     40.13624191
# ...

# %%
df.columns[2:]
# Out:
# Index(['[1] 331 SWATH.htrms.PG.Quantity', '[2] 339 SWATH.htrms.PG.Quantity',
#        '[3] 378 SWATH.htrms.PG.Quantity', '[4] 403 SWATH.htrms.PG.Quantity',
#        '[5] 412 SWATH.htrms.PG.Quantity', '[6] 415 SWATH.htrms.PG.Quantity',
#        '[7] 422 SWATH_IR.htrms.PG.Quantity', '[8] 423 SWATH.htrms.PG.Quantity',
#        '[9] 424 SWATH.htrms.PG.Quantity', '[10] 425 SWATH.htrms.PG.Quantity',
#        ...
#        '[108] 879 SWATH.htrms.PG.Quantity',
#        '[109] 886 SWATH.htrms.PG.Quantity',
#        '[110] 890 SWATH.htrms.PG.Quantity',
#        '[111] 892 SWATH.htrms.PG.Quantity',
#        '[112] 897 SWATH.htrms.PG.Quantity',
#        '[113] 899_SWATH.htrms.PG.Quantity',
#        '[114] 944_SWATH.htrms.PG.Quantity',
#        '[115] 981 SWATH.htrms.PG.Quantity',
#        '[116] 983 SWATH.htrms.PG.Quantity',
#        '[117] 1059 SWATH.htrms.PG.Quantity'],
#       dtype='object', length=116)

# %%
df.sum(axis =1)
# Out:
# 0        12468.06
# 1        12440.85
# 2        12331.71
# 3        12956.74
# 4        12711.51
#           ...
# 3846     49960.70
# 3847    553276.75
# 3848     54284.03
# 3849     51641.10
# 3850    111076.49
# Length: 3851, dtype: float64

# %%
df
# Out:
#       PG.MolecularWeight  PG.Genes [1] 331 SWATH.htrms.PG.Quantity  \
# 0               12468.06  IGLV7-46                               0
# 1               12440.85  IGLV3-10                               0
# 2               12331.71   IGLV3-9                               0
# 3               12956.74  IGKV2-28                     34.48708725
# 4               12711.51  IGKV1-27                               0
# ...                  ...       ...                             ...
# 3846            49960.70      SQOR                     417.9597778
# 3847           553276.75      PCLO                     2697.338135
# 3848            54284.03     WASF2                     71.50621033
# 3849            51641.10     ENPP4                     21.08303261
# 3850           111076.49   SEC23IP                      65.0891571
#
#      [2] 339 SWATH.htrms.PG.Quantity [3] 378 SWATH.htrms.PG.Quantity  \
# 0                                  0                     142.5664215
# ...

# %%
sample = df.iloc[:,2:]

# %%
sample
# Out:
#      [1] 331 SWATH.htrms.PG.Quantity [2] 339 SWATH.htrms.PG.Quantity  \
# 0                                  0                               0
# 1                                  0                               0
# 2                                  0                               0
# 3                        34.48708725                     32.86564255
# 4                                  0                               0
# ...                              ...                             ...
# 3846                     417.9597778                     266.9935303
# 3847                     2697.338135                     2533.971436
# 3848                     71.50621033                      86.6569519
# 3849                     21.08303261                     27.59094048
# 3850                      65.0891571                     62.91896439
#
#      [3] 378 SWATH.htrms.PG.Quantity [4] 403 SWATH.htrms.PG.Quantity  \
# ...

# %%
sum_column = sample.sum(axis=0)

# %%
sum_column
# Out:
# Series([], dtype: float64)

# %%
sample
# Out:
#      [1] 331 SWATH.htrms.PG.Quantity [2] 339 SWATH.htrms.PG.Quantity  \
# 0                                  0                               0
# 1                                  0                               0
# 2                                  0                               0
# 3                        34.48708725                     32.86564255
# 4                                  0                               0
# ...                              ...                             ...
# 3846                     417.9597778                     266.9935303
# 3847                     2697.338135                     2533.971436
# 3848                     71.50621033                      86.6569519
# 3849                     21.08303261                     27.59094048
# 3850                      65.0891571                     62.91896439
#
#      [3] 378 SWATH.htrms.PG.Quantity [4] 403 SWATH.htrms.PG.Quantity  \
# ...

# %%
sample.columns
# Out:
# Index(['[1] 331 SWATH.htrms.PG.Quantity', '[2] 339 SWATH.htrms.PG.Quantity',
#        '[3] 378 SWATH.htrms.PG.Quantity', '[4] 403 SWATH.htrms.PG.Quantity',
#        '[5] 412 SWATH.htrms.PG.Quantity', '[6] 415 SWATH.htrms.PG.Quantity',
#        '[7] 422 SWATH_IR.htrms.PG.Quantity', '[8] 423 SWATH.htrms.PG.Quantity',
#        '[9] 424 SWATH.htrms.PG.Quantity', '[10] 425 SWATH.htrms.PG.Quantity',
#        ...
#        '[108] 879 SWATH.htrms.PG.Quantity',
#        '[109] 886 SWATH.htrms.PG.Quantity',
#        '[110] 890 SWATH.htrms.PG.Quantity',
#        '[111] 892 SWATH.htrms.PG.Quantity',
#        '[112] 897 SWATH.htrms.PG.Quantity',
#        '[113] 899_SWATH.htrms.PG.Quantity',
#        '[114] 944_SWATH.htrms.PG.Quantity',
#        '[115] 981 SWATH.htrms.PG.Quantity',
#        '[116] 983 SWATH.htrms.PG.Quantity',
#        '[117] 1059 SWATH.htrms.PG.Quantity'],
#       dtype='object', length=116)

# %%
sample = sample.rename(columns = {'[1] 331 SWATH.htrms.PG.Quantity':'331'})

# %%
sample.columns
# Out:
# Index(['331', '[2] 339 SWATH.htrms.PG.Quantity',
#        '[3] 378 SWATH.htrms.PG.Quantity', '[4] 403 SWATH.htrms.PG.Quantity',
#        '[5] 412 SWATH.htrms.PG.Quantity', '[6] 415 SWATH.htrms.PG.Quantity',
#        '[7] 422 SWATH_IR.htrms.PG.Quantity', '[8] 423 SWATH.htrms.PG.Quantity',
#        '[9] 424 SWATH.htrms.PG.Quantity', '[10] 425 SWATH.htrms.PG.Quantity',
#        ...
#        '[108] 879 SWATH.htrms.PG.Quantity',
#        '[109] 886 SWATH.htrms.PG.Quantity',
#        '[110] 890 SWATH.htrms.PG.Quantity',
#        '[111] 892 SWATH.htrms.PG.Quantity',
#        '[112] 897 SWATH.htrms.PG.Quantity',
#        '[113] 899_SWATH.htrms.PG.Quantity',
#        '[114] 944_SWATH.htrms.PG.Quantity',
#        '[115] 981 SWATH.htrms.PG.Quantity',
#        '[116] 983 SWATH.htrms.PG.Quantity',
#        '[117] 1059 SWATH.htrms.PG.Quantity'],
#       dtype='object', length=116)

# %%
sample.columns[0]
# Out:
# '331'

# %%
sample.columns.str.split(" ").str[1]
# Out:
# Index([                          nan,                         '339',
#                                '378',                         '403',
#                                '412',                         '415',
#                                '422',                         '423',
#                                '424',                         '425',
#        ...
#                                '879',                         '886',
#                                '890',                         '892',
#                                '897', '899_SWATH.htrms.PG.Quantity',
#        '944_SWATH.htrms.PG.Quantity',                         '981',
#                                '983',                        '1059'],
#       dtype='object', length=116)

# %%
sample
# Out:
#               331 [2] 339 SWATH.htrms.PG.Quantity  \
# 0               0                               0
# 1               0                               0
# 2               0                               0
# 3     34.48708725                     32.86564255
# 4               0                               0
# ...           ...                             ...
# 3846  417.9597778                     266.9935303
# 3847  2697.338135                     2533.971436
# 3848  71.50621033                      86.6569519
# 3849  21.08303261                     27.59094048
# 3850   65.0891571                     62.91896439
#
#      [3] 378 SWATH.htrms.PG.Quantity [4] 403 SWATH.htrms.PG.Quantity  \
# 0                        142.5664215                               0
# 1                                  0                               0
# 2                        11.79787827                               0
# 3                        154.7983246                     41.60778809
# ...

# %%
sample.sum(axis=0, skipna=True)
# Out:
# Series([], dtype: float64)

# %%
sample['total'] = sample.sum(axis=0,skipna=True)

# %%
sample['total']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3846   NaN
# 3847   NaN
# 3848   NaN
# 3849   NaN
# 3850   NaN
# Name: total, Length: 3851, dtype: float64

# %%
sample.head(10)
# Out:
#            331 [2] 339 SWATH.htrms.PG.Quantity  \
# 0            0                               0
# 1            0                               0
# 2            0                               0
# 3  34.48708725                     32.86564255
# 4            0                               0
# 5   77.0422821                     105.1361084
# 6  77.58589172                     88.03645325
# 7            0                               0
# 8            0                               0
# 9  40.62528992                               0
#
#   [3] 378 SWATH.htrms.PG.Quantity [4] 403 SWATH.htrms.PG.Quantity  \
# 0                     142.5664215                               0
# 1                               0                               0
# 2                     11.79787827                               0
# 3                     154.7983246                     41.60778809
# 4                     38.21081924                               0
# ...

# %%
sample_sum = sample.sum(axis=0, skipna=True)

# %%
print(sample_sum)
# Out:
# total    0.0
# dtype: float64

# %%
sum = 3 + 6

# %%
sum
# Out:
# 9

# %%
datatypes = sample.dtypes

# %%
print(datatypes.head(10))
# Out:
# 331                                   object
# [2] 339 SWATH.htrms.PG.Quantity       object
# [3] 378 SWATH.htrms.PG.Quantity       object
# [4] 403 SWATH.htrms.PG.Quantity       object
# [5] 412 SWATH.htrms.PG.Quantity       object
# [6] 415 SWATH.htrms.PG.Quantity       object
# [7] 422 SWATH_IR.htrms.PG.Quantity    object
# [8] 423 SWATH.htrms.PG.Quantity       object
# [9] 424 SWATH.htrms.PG.Quantity       object
# [10] 425 SWATH.htrms.PG.Quantity      object
# dtype: object

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3851 entries, 0 to 3850
# Columns: 117 entries, 331 to total
# dtypes: float64(1), object(116)
# memory usage: 3.4+ MB

# %%
sample.describe()
# Out:
#        total
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
dataTypeDict = dict(sample.dtypes)
print('Data type of each column of Dataframe :')
print(dataTypeDict)
# Out:
# Data type of each column of Dataframe :
# ...

# %%
sample
# Out:
#               331 [2] 339 SWATH.htrms.PG.Quantity  \
# 0               0                               0
# 1               0                               0
# 2               0                               0
# 3     34.48708725                     32.86564255
# 4               0                               0
# ...           ...                             ...
# 3846  417.9597778                     266.9935303
# 3847  2697.338135                     2533.971436
# 3848  71.50621033                      86.6569519
# 3849  21.08303261                     27.59094048
# 3850   65.0891571                     62.91896439
#
#      [3] 378 SWATH.htrms.PG.Quantity [4] 403 SWATH.htrms.PG.Quantity  \
# 0                        142.5664215                               0
# 1                                  0                               0
# 2                        11.79787827                               0
# 3                        154.7983246                     41.60778809
# ...

# %%
sample.astype('float')
# Out:
#               331  [2] 339 SWATH.htrms.PG.Quantity  \
# 0        0.000000                         0.000000
# 1        0.000000                         0.000000
# 2        0.000000                         0.000000
# 3       34.487087                        32.865643
# 4        0.000000                         0.000000
# ...           ...                              ...
# 3846   417.959778                       266.993530
# 3847  2697.338135                      2533.971436
# 3848    71.506210                        86.656952
# 3849    21.083033                        27.590940
# 3850    65.089157                        62.918964
#
#       [3] 378 SWATH.htrms.PG.Quantity  [4] 403 SWATH.htrms.PG.Quantity  \
# 0                          142.566421                         0.000000
# 1                            0.000000                         0.000000
# 2                           11.797878                         0.000000
# ...

# %%
sum_sample = sample.sum(axis=0)

# %%
sum_sample
# Out:
# total    0.0
# dtype: float64

# %%
sum_sample.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-821ba218c727> in <module>
# ----> 1 sum_sample.info()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
sample.describe()
# Out:
#        total
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
sample.head(10)
# Out:
#            331 [2] 339 SWATH.htrms.PG.Quantity  \
# 0            0                               0
# 1            0                               0
# 2            0                               0
# 3  34.48708725                     32.86564255
# 4            0                               0
# 5   77.0422821                     105.1361084
# 6  77.58589172                     88.03645325
# 7            0                               0
# 8            0                               0
# 9  40.62528992                               0
#
#   [3] 378 SWATH.htrms.PG.Quantity [4] 403 SWATH.htrms.PG.Quantity  \
# 0                     142.5664215                               0
# 1                               0                               0
# 2                     11.79787827                               0
# 3                     154.7983246                     41.60778809
# 4                     38.21081924                               0
# ...

# %%
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
sum = sample.iloc[3,0] + sample.iloc[9,0]

# %%
sum
# Out:
# '34.4870872540.62528992'

# %%
print(sample.head(10).dtypes)
# Out:
# 331                                    object
# [2] 339 SWATH.htrms.PG.Quantity        object
# [3] 378 SWATH.htrms.PG.Quantity        object
# [4] 403 SWATH.htrms.PG.Quantity        object
# [5] 412 SWATH.htrms.PG.Quantity        object
#                                        ...
# [114] 944_SWATH.htrms.PG.Quantity      object
# [115] 981 SWATH.htrms.PG.Quantity      object
# [116] 983 SWATH.htrms.PG.Quantity      object
# [117] 1059 SWATH.htrms.PG.Quantity     object
# total                                 float64
# Length: 117, dtype: object

# %%
pd.to_numeric(sample['331'])
# Out:
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3         34.487087
# 4          0.000000
#            ...
# 3846     417.959778
# 3847    2697.338135
# 3848      71.506210
# 3849      21.083033
# 3850      65.089157
# Name: 331, Length: 3851, dtype: float64
